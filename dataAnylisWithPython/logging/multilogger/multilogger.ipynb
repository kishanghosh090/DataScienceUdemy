# %%
import logging

## create logger for module 1

logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

## create logger for module 2

logger2 = logging.getLogger("module2")
logger2.setLevel(logging.ERROR)

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# %%
## log messages from different logger

logger1.debug("this is a debug message for logger 1")
logger2.error("this is a warning message for logger 2")
# Out:
# 2025-09-14 21:21:08 - module1 - DEBUG - this is a debug message for logger 1
# 2025-09-14 21:21:08 - module2 - ERROR - this is a warning message for logger 2
